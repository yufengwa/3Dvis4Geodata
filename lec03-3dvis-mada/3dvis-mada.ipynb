# %% [markdown]
# 地学数据三维可视化课件第三节：Madagascar

# %% [markdown]
# # <center>地学数据三维可视化-Madagascar</center>
# <br/>
#
# <center><img src="./figs/snaps2.gif" style="float: center; height:300px" /><center>
# <br/>
#
# <div style="clear: both"></div>
# <center>汪宇锋</center>
# <div style="clear: both"></div>
# <center>地球物理与空间信息学院</center>
# <div style="clear: both"></div>
# <center>2021年11月</center>

# %% [markdown]
# ## 开源研究
# <br/>
#
# <table>
#   <tr>
#     <td><img src="./figs/unixart.png" width="1000" /></td>
#     <td>“Abandoning the habit of secrecy in favor of process transparency and peer review was the crucial step by which alchemy became chemistry. In the same way, it is beginning to appear that open-source development may signal the long-awaited maturation of software development as a discipline.” <br/>
#         -- Eric Raymond </td>
#   </tr>
#  </table>

# %% [markdown]
# ## 开源研究
# <br/>
#
# <table>
#   <tr>
#     <td><img src="./figs/claerbout.jpg" width="1000" /></td>
#     <td>“An article about computational science in a scientific publication is not the scholarship itself, it is merely advertising of the scholarship. The actual scholarship is the complete software development environment and the complete set of instructions which generated the figures.” <br/>
#         -- Jon Claerbout </td>
#   </tr>
#  </table>

# %% [markdown]
# ## 开源研究
# <br/>
#
# <table>
#   <tr>
#     <td><img src="./figs/Harold.jpeg" width="800" /></td>
#     <td>“We want ideas, and in particular programs, that work in one place to work elsewhere. One form of objectivity is that published science must work elsewhere than just in the author's laboratory or even just in the author's imagination; this requirement is called reproducibility.” <br/>
#         -- Harold Thimbleby </td>
#   </tr>
#  </table>

# %% [markdown]
# ## 开源研究
# <br/>
#
# <table>
#   <tr>
#     <td><img src="./figs/donoho.jpeg" width="1500" /></td>
#     <td>“Scientific computation is emerging as absolutely central to the scientific method, but the prevalence of very relaxed practices is leading to a credibility crisis. Reproducible computational research, in which all details of computations—code and data—are made conveniently available to others, is a necessary response to this crisis. The authors review their approach to reproducible research and describe how it has evolved over time, discussing the arguments for and against working reproducibly.” <br/>
#         -- David L. Donoho </td>
#   </tr>
#  </table>

# %% [markdown]
# ## 开源研究
# <br/>
#
# <table>
#   <tr>
#     <td><img src="./figs/fomel.jpeg" width="2000" /></td>
#     <td>“Despite our poor ability to get new adherents to the philosophy of reproducible research, we continued producing maybe 800 pages a year of documents in signal and image processing, steadily honing our skills at doing so. Although I always made the claim (which was true) that reproducibility was essential to pass wisdom on to the next generation, our experience was always that the most likely recipient would be the author herself at a later stage of life.” <br/>
#         -- Sergey Fomel, 2009 </td>
#   </tr>
#  </table>

# %% [markdown]
# ## [Madagascar](https://www.reproducibility.org)
# <br/>
#
#
# <center><img src="./figs/madagascar.jpg" width="800" /></center>

# %% [markdown]
# ## [Madagascar](https://www.reproducibility.org)
# <br/>
#
# <table>
#   <tr>
#     <td><img src="./figs/pyramid1.jpg" width="400" /></td>
#     <td><img src="./figs/pyramid2.jpg" width="400" /></td>
#     <td><img src="./figs/pyramid3.jpg" width="450" /></td>
#   </tr>
#  </table>

# %% [markdown]
# ## [Madagascar](https://www.reproducibility.org)
# <br/>
#
# <center><img src="./figs/madavisit.png" width="800" /></center>

# %% [markdown]
# ## [Madagascar](https://www.reproducibility.org)
# <br/>
#
# <center><img src="./figs/schools.jpg" width="800" /></center>

# %% [markdown]
# ## [Madagascar](https://www.reproducibility.org)
# <br/>
#
# <center><img src="./figs/contrib.jpg" width="800" /></center>

# %% [markdown]
# ## [Madagascar](https://www.reproducibility.org)
# <br/>
#
# [<center><img src="./figs/programs.jpg" width="600" /></center>](https://reproducibility.org/RSF/)

# %% [markdown]
# ## [Madagascar开源研究](https://www.reproducibility.org/wiki/Reproducible_Documents)
# <br/>
#
# <center><img src="./figs/repro.jpg" width="800" /></center>

# %% [markdown]
# ## [Madagascar开源研究](https://www.reproducibility.org/wiki/Reproducible_Documents)
# <br/>
#
# <center><img src="./figs/scons.jpg" width="800" /></center>

# %% [markdown]
# ## [Madagascar安装](https://www.reproducibility.org/wiki/Installation)
# <br/>
#
# - `git clone https://github.com/ahay/src RSFSRC`
# - `./configure --prefix=/directory/where/you/want/madagascar/installed`
# - `make install`
# - `source ~/RSFSRC/share/madagascar/etc/env.sh`
# - `export DATAPATH=~/RSFDATA/`

# %%
from m8r import view

# %%
# %%file test.scons
#
# from rsf.proj import *
# Flow('filter',None,'spike n1=1000 k1=300 | bandpass fhi=2 phase=y')
# Result('filter','wiggle clip=0.02 title="Welcome to Madagascar"')
#
# End()
# Out:
# Overwriting test.scons

# %%
view("filter")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm filter.png
# scons -Qf SConstruct.jupyter  filter.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/filter.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/filter.vpl filter.png )
# scons: *** Do not know how to make File target `filter.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/filter.png).  Stop.
# scons: `Fig/filter.vpl' is up to date.
# /Users/wangyufeng/RSFROOT/bin/gdpen fat=3 serifs=n bgcolor=w type=png Fig/filter.vpl > filter.png

# %% [markdown]
# ## Madagascar实例
# <br/>
#
# <table>
#   <tr>
#     <td><img src="./figs/don.gif" width="1500" /></td>
#     <td> <p>Literate programming is a concept promoted by Donald Knuth, the famous computer scientist (and the author of the Art of Computer Programming.) According to this concept, computer programs should be written in a combination of the programming language (the usual source code) and the natural language, which explains the logic of the program. </p> </td>
#   </tr>
#  </table>

# %%
# %%file 1_velvel.scons
#
#
# Flow('mod',None,
#      '''
#      spike n1=75 n2=35 d1=0.0533333 d2=0.0242157 o1=0 o2=0.01
#      nsp=5 mag=2,1,1,1,1 k1=11,18,33,56,70 k2=28,19,19,19,19
#      ''')
# Flow('dat','mod','velmod h0=-1 dh=0.141026 nh=40 slowness=y half=n')
# Flow('mod2','dat','vscan slowness=y half=n')
# Flow('dat2','mod2','velmod slowness=y half=n')
#
# for data in ('mod','dat','mod2','dat2'):
#     Plot(data,
#          '''
#          dots gaineach=0 dots=0 seemean=1 strings=0
#          constsep=1 overlap=6. transp=1 label1=" "
#          ''')
# Result('velvel','mod dat mod2 dat2','TwoRows')
# Out:
# Overwriting 1_velvel.scons

# %%
view("velvel")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm velvel.png
# scons -Qf SConstruct.jupyter  velvel.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/velvel.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/velvel.vpl velvel.png )
# scons: *** Do not know how to make File target `velvel.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/velvel.png).  Stop.
# scons: `Fig/velvel.vpl' is up to date.
# /Users/wangyufeng/RSFROOT/bin/gdpen fat=3 serifs=n bgcolor=w type=png Fig/velvel.vpl > velvel.png

# %%
# %%file 2_mutvel.scons
#
#
# #Fetch('midpts.hh','midpts')
#
# Flow('cdp','midpts.hh','window n3=1 j1=2 | dd form=native')
# Flow('mutter','cdp','mutter half=n v0=1.4')
# Flow('veltran','mutter','vscan slowness=y half=n v0=0.3 nv=81 dv=0.005')
#
# sides = ['mutter','veltran']
# for case in sides:
#     Plot(case,'grey wanttitle=n')
# Result('mutvel',sides,'SideBySideAniso',vppen='txscale=1.5')
# Out:
# Overwriting 2_mutvel.scons

# %%
view("mutvel")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm mutvel.png
# scons -Qf SConstruct.jupyter  mutvel.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/mutvel.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/mutvel.vpl mutvel.png )
# scons: *** Do not know how to make File target `mutvel.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/mutvel.png).  Stop.
# scons: `Fig/mutvel.vpl' is up to date.
# /Users/wangyufeng/RSFROOT/bin/gdpen fat=3 serifs=n bgcolor=w type=png Fig/mutvel.vpl > mutvel.png

# %%
# %%file 3_fit.scons
#
#
# Flow('wgmutter','midpts.hh','dd form=native | mutter half=n v0=1.4')
#
# Flow('wgsmb','wgmutter',
#      'vscan slowness=y half=n v0=0.3 nv=81 dv=0.005 semblance=y',split=[3,250])
# Flow('wgfit','wgsmb','pick rect1=17 rect2=17 vel0=0.7')
#
# def graph(col=7,fat=1):
#     return '''
#     graph min2=0.3 max2=0.7 pad=n transp=y yreverse=y wanttitle=n
#     plotcol=%d plotfat=%d wantaxis=n
#     ''' % (col,fat)
#
# Flow('fit','wgfit','window n3=1')
# Plot('slow',   'fit',graph(1,1))
# Plot('fatslow','fit',graph(0,7))
# Result('fit','veltran fatslow slow','Overlay')
# Out:
# Writing 3_fit.scons

# %%
view("fit")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons 3_fit.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm fit.png
# scons -Qf SConstruct.jupyter  fit.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/fit.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/fit.vpl fit.png )
# rm: fit.png: No such file or directory
# make: [fit.png] Error 1 (ignored)
# scons: *** Do not know how to make File target `fit.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/fit.png).  Stop.
# < midpts.hh /Users/wangyufeng/RSFROOT/bin/sfdd form=native | /Users/wangyufeng/RSFROOT/bin/sfmutter half=n v0=1.4 > wgmutter.rsf
# sfmutter: CDPtype=2
# < wgmutter.rsf /Users/wangyufeng/RSFROOT/bin/sfvscan slowness=y half=n v0=0.3 nv=81 dv=0.005 semblance=y > wgsmb.rsf
# sfvscan: CDPtype=2
# sfvscan: cmp 250 of 250;
# sfpick: cmp 35 of 250;
# ...

# %%
# %%file 4_wgstack.scons
#
#
# Flow('wgstack',['wgmutter','wgfit'],
#      'nmo velocity=${SOURCES[1]} slowness=y half=n | stack')
# Result('wgstack','grey title=Stack')
# Out:
# Writing 4_wgstack.scons

# %%
view("wgstack")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons 3_fit.scons 4_wgstack.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm wgstack.png
# scons -Qf SConstruct.jupyter  wgstack.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/wgstack.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/wgstack.vpl wgstack.png )
# rm: wgstack.png: No such file or directory
# make: [wgstack.png] Error 1 (ignored)
# scons: *** Do not know how to make File target `wgstack.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/wgstack.png).  Stop.
# < wgmutter.rsf /Users/wangyufeng/RSFROOT/bin/sfnmo velocity=wgfit.rsf slowness=y half=n | /Users/wangyufeng/RSFROOT/bin/sfstack > wgstack.rsf
# sfnmo: CDPtype=2
# sfnmo: CMP 250 of 250;
# < wgstack.rsf /Users/wangyufeng/RSFROOT/bin/sfgrey title=Stack > Fig/wgstack.vpl
# ...

# %%
# %%file 5_wgpick.scons
#
#
# Flow('wgpick','wgstack','shearer short=20 long=200 rect2=5')
# Result('wgpick','grey color=j allpos=y title=Picking')
# Out:
# Writing 5_wgpick.scons

# %%
view("wgpick")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons 3_fit.scons 4_wgstack.scons 5_wgpick.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm wgpick.png
# scons -Qf SConstruct.jupyter  wgpick.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/wgpick.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/wgpick.vpl wgpick.png )
# rm: wgpick.png: No such file or directory
# make: [wgpick.png] Error 1 (ignored)
# scons: *** Do not know how to make File target `wgpick.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/wgpick.png).  Stop.
# < wgstack.rsf /Users/wangyufeng/RSFROOT/bin/sfshearer short=20 long=200 rect2=5 > wgpick.rsf
# < wgpick.rsf /Users/wangyufeng/RSFROOT/bin/sfgrey color=j allpos=y title=Picking > Fig/wgpick.vpl
# sfshearer: iteration 0 res: 0.001869 grad: 0.000000
# sfshearer: iteration 1 res: 0.001097 grad: 0.440525
# ...

# %%
# %%file 6_agcstack.scons
#
#
# Flow('agcstack','wgstack','agc')
# Result('agcstack','grey title="AGC Stack" ')
# Out:
# Writing 6_agcstack.scons

# %%
view("agcstack")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons 3_fit.scons 4_wgstack.scons 5_wgpick.scons 6_agcstack.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm agcstack.png
# scons -Qf SConstruct.jupyter  agcstack.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/agcstack.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/agcstack.vpl agcstack.png )
# rm: agcstack.png: No such file or directory
# make: [agcstack.png] Error 1 (ignored)
# scons: *** Do not know how to make File target `agcstack.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/agcstack.png).  Stop.
# < wgstack.rsf /Users/wangyufeng/RSFROOT/bin/sfagc > agcstack.rsf
# < agcstack.rsf /Users/wangyufeng/RSFROOT/bin/sfgrey title="AGC Stack" > Fig/agcstack.vpl
# /Users/wangyufeng/RSFROOT/bin/gdpen fat=3 serifs=n bgcolor=w type=png Fig/agcstack.vpl > agcstack.png

# %%
# %%file 7_wgvel.scons
#
#
# Flow('weight',['wgsmb','wgfit'],'slice pick=${SOURCES[1]}')
# Flow('wgrms','wgfit','window | math output=1/input')
# Flow(['wgint','wgrms2'],['wgrms','weight'],
#      '''
#      dix weight=${SOURCES[1]} vrmsout=${TARGETS[1]}
#      rect1=10 rect2=10
#      ''')
#
# def velplot(title):
#     return '''
#     grey color=j scalebar=y barlabel="%s (km/s)" allpos=y bias=1.4
#     bartype=h wherebarlabel=b wanttitle=n
#     ''' % title
#
# Plot('wgrms','wgrms',velplot("RMS velocity"))
# Plot('wgint','wgint',velplot("Interval velocity"))
# Result('wgvel','wgrms wgint','SideBySideAniso')
# Out:
# Writing 7_wgvel.scons

# %%
view("wgvel")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons 3_fit.scons 4_wgstack.scons 5_wgpick.scons 6_agcstack.scons 7_wgvel.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm wgvel.png
# scons -Qf SConstruct.jupyter  wgvel.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/wgvel.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/wgvel.vpl wgvel.png )
# rm: wgvel.png: No such file or directory
# make: [wgvel.png] Error 1 (ignored)
# scons: *** Do not know how to make File target `wgvel.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/wgvel.png).  Stop.
# < wgfit.rsf /Users/wangyufeng/RSFROOT/bin/sfwindow | /Users/wangyufeng/RSFROOT/bin/sfmath output=1/input > wgrms.rsf
# < wgrms.rsf /Users/wangyufeng/RSFROOT/bin/sfgrey color=j scalebar=y barlabel="RMS velocity (km/s)" allpos=y bias=1.4 bartype=h wherebarlabel=b wanttitle=n > wgrms.vpl
# ...

# %%
# %%file 8_wgvel2.scons
#
#
# Plot('wgrms2','wgrms2',velplot("Predicted RMS velocity"))
# Result('wgvel2','wgrms wgrms2','SideBySideAniso')
# Out:
# Writing 8_wgvel2.scons

# %%
view("wgvel2")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons 3_fit.scons 4_wgstack.scons 5_wgpick.scons 6_agcstack.scons 7_wgvel.scons 8_wgvel2.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm wgvel2.png
# scons -Qf SConstruct.jupyter  wgvel2.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/wgvel2.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/wgvel2.vpl wgvel2.png )
# rm: wgvel2.png: No such file or directory
# make: [wgvel2.png] Error 1 (ignored)
# scons: *** Do not know how to make File target `wgvel2.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/wgvel2.png).  Stop.
# < wgrms2.rsf /Users/wangyufeng/RSFROOT/bin/sfgrey color=j scalebar=y barlabel="Predicted RMS velocity (km/s)" allpos=y bias=1.4 bartype=h wherebarlabel=b wanttitle=n > wgrms2.vpl
# ...

# %%
# %%file 9_wgvel1.scons
#
#
# def velgraph(title,max):
#     return '''
#     window n2=1 |
#     graph wanttitle=n transp=y yreverse=y label2="%s (km/s)"
#     min2=1.4 max2=%g
#     ''' % (title,max)
#
# Plot('rms1','wgrms',velgraph("RMS velocity",2.4))
# Plot('rms2','wgrms2',velgraph(" ",2.4) + ' dash=1 wantaxis=n')
# Plot('rms','rms1 rms2','Overlay')
# Plot('int','wgint',velgraph("Interval velocity",3))
# Result('wgvel1','rms int','SideBySideAniso')
# Out:
# Writing 9_wgvel1.scons

# %%
view("wgvel1")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons 3_fit.scons 4_wgstack.scons 5_wgpick.scons 6_agcstack.scons 7_wgvel.scons 8_wgvel2.scons 9_wgvel1.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm wgvel1.png
# scons -Qf SConstruct.jupyter  wgvel1.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/wgvel1.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/wgvel1.vpl wgvel1.png )
# rm: wgvel1.png: No such file or directory
# make: [wgvel1.png] Error 1 (ignored)
# scons: *** Do not know how to make File target `wgvel1.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/wgvel1.png).  Stop.
# < wgrms.rsf /Users/wangyufeng/RSFROOT/bin/sfwindow n2=1 | /Users/wangyufeng/RSFROOT/bin/sfgraph wanttitle=n transp=y yreverse=y label2="RMS velocity (km/s)" min2=1.4 max2=2.4 > rms1.vpl
# ...

# %% [markdown]
# ## Madagascar三维可视化
# <br/>
#
# **sfgrey3** generates “cube” plots from 3-D data. Some of the options specific to this kind of display are:
#
# - flat=y/n The flat parameter tells sfgrey3 whether to display the cube as a flat image or in a 3-D projection.
# - frame1=, frame2=, frame3= The frame parameters select the slices from the cube to be displayed in the plot.

# %% [markdown]
# ## Madagascar三维可视化
# <br/>
#
# - point1=, point2= The point1= and point2= parameters control the aspect ratio of the cube in the vertical and the horizontal dimension, respectively.
# - movie=y/n The movie parameter allows the user to create a movie looping over slices in a cube instead of a static picture.

# %%
# %%file 3dcube.scons
#
# #Fetch('shots.hh','shots')
#
# Flow('cube','shots.hh','dd form=native | window n1=400 n2=24 | byte')
#
# cubeplot = '''
# grey3 frame1=320 frame2=3 frame3=20 point1=.75
# label1="Time (s)" label2=Offset label3=Shot wanttitle=n
# '''
#
# Plot('flat','cube',cubeplot)
# Plot('cube',cubeplot + ' flat=n')
# Result('cube','flat cube','OverUnderAniso')
# Out:
# Writing 3dcube.scons

# %%
view("cube")
# Out:
# echo "from rsf.proj import *" > SConstruct.jupyter
# cat 1_velvel.scons 2_mutvel.scons 3_fit.scons 3dcube.scons 4_wgstack.scons 5_wgpick.scons 6_agcstack.scons 7_wgvel.scons 8_wgvel2.scons 9_wgvel1.scons test.scons >> SConstruct.jupyter
# echo "" >> SConstruct.jupyter
# echo "End()" >> SConstruct.jupyter
# rm cube.png
# scons -Qf SConstruct.jupyter  cube.png || ( \
# 	scons -Qf SConstruct.jupyter Fig/cube.vpl && \
# 	vpconvert pen=gd fat=3 serifs=n bgcolor=w Fig/cube.vpl cube.png )
# rm: cube.png: No such file or directory
# make: [cube.png] Error 1 (ignored)
# scons: *** Do not know how to make File target `cube.png' (/Users/wangyufeng/Desktop/Research/Geophysics/Resources/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/cube.png).  Stop.
# < shots.hh /Users/wangyufeng/RSFROOT/bin/sfdd form=native | /Users/wangyufeng/RSFROOT/bin/sfwindow n1=400 n2=24 | /Users/wangyufeng/RSFROOT/bin/sfbyte > cube.rsf
# ...

# %% [markdown]
# ### Clean

# %%
# !scons -cQ
# Out:
# Removed mod.rsf
# Removed /Users/wangyufeng/data/datapath/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/mod.rsf@
# Removed dat.rsf
# Removed /Users/wangyufeng/data/datapath/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/dat.rsf@
# Removed mod2.rsf
# Removed /Users/wangyufeng/data/datapath/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/mod2.rsf@
# Removed dat2.rsf
# Removed /Users/wangyufeng/data/datapath/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/dat2.rsf@
# Removed mod.vpl
# Removed dat.vpl
# Removed mod2.vpl
# Removed dat2.vpl
# Removed Fig/velvel.vpl
# Removed cdp.rsf
# Removed /Users/wangyufeng/data/datapath/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/cdp.rsf@
# Removed mutter.rsf
# Removed /Users/wangyufeng/data/datapath/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/mutter.rsf@
# Removed veltran.rsf
# Removed /Users/wangyufeng/data/datapath/GeoVisual/3Dvis4Geodata/lec03-3dvis-mada/veltran.rsf@
# Removed mutter.vpl
# Removed veltran.vpl
# Removed Fig/mutvel.vpl
# Removed wgmutter.rsf
# ...

# %% [markdown]
# # 下节课预告
# <br/>
#
# <center class="half">
#     <img src="./figs/Camera.gif" style="float: center; width:600px"/>
# </center>
